# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# class Solution:
#     def isMatch(self, s: str, p: str) -> bool:
#         if p == '.*':
#             return True
        
#         dotable = False
#         starable = False

#         for c in s[::-1]:
#             if c == '.':
#                 dotable = True
#             if c == '*':
#                 starable = True
#                 repeat_char = ''
            
#             if c not in p:
#                 return False
#         return True

# %%
"""
  r        r        r   
s|a      s|ab     s|ab  
-|- -    -|-- -   -|-- -
a|1 1    a|10 1   a|10 1
b|0 0    b|01 1   b|01 1
c|0 0    c|00 0   c|00 0

  r        r        r        r    
s|a*     s|ab*    s|ab.    s|a.*  
-|-- -   -|--- -  -|--- -  -|--- -
a|11 1   a|100 0  a|101 0  a|111 1
a|01 1   a|100 1  a|101 1  a|111 1
b|00 0   b|011 1  b|011 1  b|011 1
c|00 0   b|011 1  b|011 1  c|011 1

  r   
s|a*  
-|-- -
a|11 1
a|11 1
a|11 1
a|11 1


  r                   r             
s|ab*c.dd.a.*b      s|ab*c.dd.a.*b  
-|------------ -    -|------------ -
a|100010011110 0    a|100010011110 0
a|100010011110 1    a|*00010011110 1
b|011010010111 1    b|0*1010010111 1
b|011010010111 1    b|01*010010111 1
b|011010010111 1    b|01*010010111 1
c|000110010110 1    c|000*10010110 1
d|000011110110 1    d|0000*1110110 1
d|000011110110 1    d|00001*110110 1
d|000011110110 1    d|000011*10110 1
c|000110010110 1    c|0001100*0110 1
a|100010011110 1    a|10001001*110 1
a|100010011110 1    a|100010011*10 1
a|100010011110 1    a|1000100111*0 1
a|100010011110 1    a|1000100111*0 1
a|100010011110 1    a|1000100111*0 1
b|100010011111 1    b|10001001111* 1
a|100010011110 0    a|100010011110 0


ab f
10 1
01 1
11 1
00 0

"""

# %%
# class Solution:
#     def isMatch(self, s: str, p: str) -> bool:
#         if p == '.*':
#             return True
        
#         dotable = False
#         starable = False
#         breakable = False
#         starable_firstable = True

#         lp = len(p)
        
#         lm = 0

#         print('    ', end='')
#         for i in range(len(p)):
#             print(i, end='')
#         print('')
#         print('    ', end='')
#         for i in range(len(p)):
#             print(p[i], end='')
#         print('')

#         for c in s:
#             print(f"{lm} {c} ", end='')
#             for i in range(len(p)):
#                 if i>=lm-1 and not breakable:
#                     if p[i] == '.':
#                         dotable = True
#                     if p[i] == '*':
#                         starable = True
#                         repeat_char = last_char
#                         if last_char == '.':
#                             dotable = True

#                         starable_firstable = True

#                     if c == p[i]:
#                         lm += 1
#                         print('1', end='')
#                         breakable = True
#                     elif dotable and not starable:
#                         lm +=1
#                         print('1', end='')
#                         dotable = False
#                         breakable = True
#                     elif starable and not dotable:
#                         if last_char != c:
#                             lm+=1
#                             starable = False
#                         else:
#                             print('1', end='')
#                         breakable = True
#                     elif starable and dotable:
#                         if c == p[i]:
#                             lm+=1
#                             starable = False
#                             dotable = False
#                         breakable = True
#                     else:
#                         lm = 0
#                         breakable = True
#                 else:
#                     print('0', end='')



#                 last_char = c

#                 if lp == lm:
#                     return True
            
#             breakable = False
#             print()

#         return False

# %%
# class Solution:
#     def isMatch(self, s: str, p: str) -> bool:
#         if p == '.*':
#             return True
        
#         dotable = False
#         starable = False
#         breakable = False
#         starable_firstable = True

#         lp = len(p)
#         ls = len(s)

#         if lp>ls:
#             return False
#         print(lp)
#         lm = 0

#         print('    ', end='')
#         for i in range(len(p)):
#             print(i, end='')
#         print('')
#         print('    ', end='')
#         for i in range(len(p)):
#             print(p[i], end='')
#         print('')

#         last_char = ''
#         last_binar_match = '0'*lp

#         for c in s:
#             binar_match = ''
#             print(f"{lm} {c} ", end='')
#             for i in range(len(p)):
#                 if p[i] == '.':
#                     dotable = True

#                 if c == p[i]:
#                     print('1', end='')
#                     binar_match += '1'
#                     lm=lm+1
#                 elif p[i] == '.':
#                     print('1', end='')
#                     binar_match += '1'
#                 elif p[i] == '*':
#                     if c == last_char:
#                         print('1', end='')
#                         binar_match += '1'
#                     else:
#                         print('0', end='')
#                         binar_match += '0'
#                 else:
                    
#                     lm=0
#                     print('0', end='')
#                     binar_match += '0'

#                 # if lm == lp:
#                 #     print(f"\n{lm} {c} ", end='')
#                 #     return True
#             last_char = c
#             last_binar_match = bin(int(last_binar_match, 2) | int(binar_match, 2))
            
#             breakable = False
#             print()

#         print(last_binar_match)
#         ones = 0
#         for i in bin(int(last_binar_match, 2))[2:]:
#             if i == '1':
#                 ones+=1
#                 if ones == lp:
#                     return True
#             else:
#                 ones=0


#         return False

# %%
# class Solution:
#     def isMatch(self, s: str, p: str) -> bool:
#         if p == '.*':
#             return True
        
#         dotable = False
#         starable = False
#         breakable = False
#         starable_firstable = True

#         lp = len(p)
#         ls = len(s)

#         print(lp)
#         lm = 0

#         print('    ', end='')
#         for i in range(len(p)):
#             print(i, end='')
#         print('')
#         print('    ', end='')
#         for i in range(len(p)):
#             print(p[i], end='')
#         print('')

#         last_char = ''
#         binar_matchs = []

#         for c in s:
#             binar_match = []
#             print(f"{lm} {c} ", end='')
#             for i in range(len(p)):
#                 if p[i] == '.':
#                     dotable = True

#                 if c == p[i]:
#                     print('1', end='')
#                     binar_match.append(1)
#                     lm=lm+1
#                 elif p[i] == '.':
#                     print('1', end='')
#                     binar_match.append(1)
#                 elif p[i] == '*':
#                     if c == last_char:
#                         print('1', end='')
#                         binar_match.append(1)
#                     else:
#                         print('0', end='')
#                         binar_match.append(0)
#                 else:
                    
#                     lm=0
#                     print('0', end='')
#                     binar_match.append(0)

#             binar_matchs.append(binar_match)

#             last_char = c
            
#             breakable = False
#             print()
        
#         i = 0
#         j = 0
#         lm = 0
        

#         # for bm in range(len(binar_matchs)+10):  
#         for k in range(100):
#             print(i, j) 
#             if binar_matchs[i][j] == 1 and i < ls-1:
#                 if j<lp-1:
#                     if binar_matchs[i+1][j] == 0 and binar_matchs[i+1][j+1] == 1:
#                         i+=1
#                         j+=1
#                         lm+=1
#                     elif binar_matchs[i+1][j] == 1 and binar_matchs[i+1][j+1] == 0:
#                         i+=1
#                     elif binar_matchs[i+1][j] == 1 and binar_matchs[i+1][j+1] == 1:
#                         i+=1
#                         j+=1
#                         lm+1
#                     elif binar_matchs[i][j] == 1 and binar_matchs[i+1][j+1] == 0:
#                         return False
#                 else:
#                     if binar_matchs[i+1][j] == 1:
#                         i+=1
#                     else:
#                         return False


#             else:
#                 if j == lp-1:
#                     i+=1
#                     j=0
#                 else:
#                     j+=1
#                     lm+=1
            
#             print(i, j, lp-1)

#             if j == lp-1 and i == ls-1:
#                 return True
                
#             if j >= lp-1 or i>=ls-1:
#                 break


#         return False

# %%
class Solution:
    def isMatch(self, s: str, p: str) -> bool:
        breakable = False

        s_ = s
        new_s = ''
        
        for r in p:
            if not len(s_):
                return False
 
            print(f"{0} p={r}, s_={s_}, new_s={new_s}")
            if r == s_[0]:
                new_s+=s_[0]
                s_ = s_[1:]
            elif r == '.':
                new_s+=s_[0]
                s_ = s_[1:]
            elif r == '*':
                run = True
                j=0
                while run:
                    if last_r == s_[0+j]:
                        new_s+=s_[0+j]
                        j+=1
                    else:
                        run = False
                    if not j:
                        s_ = s_[1+j:]
            else:
                pass

            # breakable = False
            last_r = r



        print(f"p={p}, s_={s_}, new_s={new_s}")
        return new_s == s

# %%
# s = 'aabbbcdddcaaaaaba'
# p = 'ab*c.dd.a.*b'

# s = 'aaaaaabaaba'
# p = 'a*ba'

s = 'aab'
p = 'c*a*b'

# s = 'aa'
# p = 'a'

# s = 'mississippi'
# p = 'mis*is*p*.'

# s = 'aaa'
# p = 'aa'

# s = 'baa'
# p = 'ba.'

# %%
sol = Solution()
sol.isMatch(s, p)
# Out:
# 0 p=c, s_=aab, new_s=
# 0 p=*, s_=aab, new_s=
# 0 p=a, s_=ab, new_s=
# 0 p=*, s_=b, new_s=a
# False

# %%
s_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1030], line 1
# ----> 1 s_
#
# NameError: name 's_' is not defined

# %%
''[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[909], line 1
# ----> 1 ''[0]
#
# IndexError: string index out of range

# %%
int('01000', 2) | int('00001', 2)
# Out:
# 9

# %%
bool(int('01000', 2) & int('00001', 2) )
# Out:
# False

# %%
for i in bin(int('01000', 2))[2:]:
    print(i)
# Out:
# 1
# 0
# 0
# 0

# %%
# Out:
# '0b1000'
