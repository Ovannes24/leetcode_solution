# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import List

# %%
"""
0
-3 -2 -1  0  0  1  2  3
 l cl cr              r
 l cl    cr           r
 l cl       cr        r
 l cl          cr     r
 l cl             cr  r -3 -2 2 3
 l    cl cr           r
 l    cl    cr        r
 l    cl       cr     r -3 -1 1 3
 l       cl cr        r -3  0 0 3
 l          cl cr     r
 l          cl    cr  r
 l             cl cr  r - 
    l cl cr           r -2 -1 0 3
    l cl    cr        r             
    l cl       cr     r             
    l cl          cr  r             
    l    cl cr        r              
    l    cl    cr     r             
    l    cl       cr  r             
    l       cl cr     r             
    l       cl    cr  r             
    l          cl cr  r             
 l cl cr           r                
 l cl    cr        r                
 l cl       cr     r                
 l cl          cr  r                
 l    cl  cr       r                
 l    cl     cr    r                
 l    cl        cr r                
 l       cl cr     r            
 l       cl     cr r   -3  0 1 2
 l          cl  cr r
 
 

 



 l cl cr           r
 l cl cr           r
 l cl cr           r
 l cl cr           r
 l cl cr           r
 l cl cr           r
 l cl cr           r
 l cl cr           r






 
 
 











"""
# Out:
# '\n0\n-3 -2 -1  0  0  1  2  3\n l cl cr              r\n l cl    cr           r\n l cl       cr        r\n l cl          cr     r\n l cl             cr  r -3 -2 2 3\n l    cl cr           r\n l    cl    cr        r\n l    cl       cr     r -3 -2 2 3\n l       cl cr        r -3  0 0 3\n l          cl cr     r\n l          cl    cr  r\n l             cl cr  r - \n    l cl cr           r\n    l cl    cr        r\n\n \n \n \n\n\n\n\n\n\n\n\n\n\n\n'

# %%
# class Solution:
#     def fourSum(self, nums: List[int], target: int) -> List[List[int]]:
#         n = sorted(nums)
#         ln = len(n)

#         l = 0
#         cl = l+1
#         cr = cl+1

#         r = ln-1

#         res = []

#         while l < r:
#             while cr<r:
#                 print(l, cl, cr, r)
#                 s = n[l]+n[cl]+n[cr]+n[r]
#                 if s == target:
#                     if [n[l], n[cl], n[cr], n[r]] not in res:
#                         res.append([n[l], n[cl], n[cr], n[r]])
#                     if len(res) > 10:
#                         return res
#                 cr+=1
#                 # while n[cr-1] == n[cr]:
#                 #     cr+=1

                
#             # print('if', l, cl, cr, r)
#             cl+=1
#             cr=cl+1

#             if r < cr:
#                 if s<target:
#                     l+=1
#                     cl = l+1
#                     cr = cl+1
#                 else:
#                     r-=1
#                     cl = l+1
#                     cr = cl+1


#         return res

# %%
# class Solution:
#     def fourSum(self, nums: List[int], target: int) -> List[List[int]]:
#         n = sorted(nums)
#         ln = len(n)

#         l = 0
#         cl = l+1
#         cr = cl+1

#         r = ln-1

#         res = []

#         while l < r:
#             while cr<r:
#                 s = n[l]+n[cl]+n[cr]+n[r]
#                 print(l, cl, cr, r, s)
#                 if s == target:
#                     if [n[l], n[cl], n[cr], n[r]] not in res:
#                         res.append([n[l], n[cl], n[cr], n[r]])
#                     if len(res) > 10:
#                         return res
                
#                 cr+=1

#             cl+=1
#             cr=cl+1

#             if cr>r:
#                 if abs(n[l]) > abs(n[r]):
#                     l += 1
#                     cl = l+1
#                     cr = cl+1
#                 elif abs(n[l]) < abs(n[r]):
#                     r-=1
#                     if l >0:
#                         l-=1
#                     cl = l+1
#                     cr = cl+1  
#                 else:
#                     l += 1
#                     cl = l+1
#                     cr = cl+1  
                    

#         return res

# %%
# class Solution:
#     def fourSum(self, nums: List[int], target: int) -> List[List[int]]:
#         n = sorted(nums)
#         ln = len(n)
        
#         if ln < 4:
#             return []
        
#         l = 0
#         cl = l+1

#         r = ln-1
#         cr = r-1

#         res = []

#         while l < r:
#             while cl<cr:
#                 s = n[l]+n[cl]+n[cr]+n[r]
#                 print(l, cl, cr, r, s)
#                 if s == target:
#                     if [n[l], n[cl], n[cr], n[r]] not in res:
#                         res.append([n[l], n[cl], n[cr], n[r]])
#                     if len(res) > 10:
#                         return res
                
#                 if s<target:
#                     cl+=1
#                 else:
#                     cr-=1
#             l+=1
#             cl = l+1

#             r = ln-1
#             cr = r-1

#         l = 0
#         cl = l+1

#         r = ln-1
#         cr = r-1
#         while l < r:
#             while cl<cr:
#                 s = n[l]+n[cl]+n[cr]+n[r]
#                 print(l, cl, cr, r, s)
#                 if s == target:
#                     if [n[l], n[cl], n[cr], n[r]] not in res:
#                         res.append([n[l], n[cl], n[cr], n[r]])
#                     if len(res) > 10:
#                         return res
                
#                 if s<target:
#                     cl+=1
#                 else:
#                     cr-=1
#             l=0
#             cl=l+1

#             r-=1
#             cr = r-1
            

                    

#         return res

# %%
class Solution:
    def fourSum(self, nums: List[int], target: int) -> List[List[int]]:
        n = sorted(nums)
        ln = len(n)

        l = 0
        cl = l+1
        cr = cl+1

        r = ln-1

        res = []

        while l < r:
            while cr<r:
                s = n[l]+n[cl]+n[cr]+n[r]
                print(l, cl, cr, r, s)
                if s == target:
                    if [n[l], n[cl], n[cr], n[r]] not in res:
                        res.append([n[l], n[cl], n[cr], n[r]])
                    if len(res) > 10:
                        return res
                
                cr+=1

            cl+=1
            cr=cl+1

            if cr>r:
                if abs(n[l]) > abs(n[r]):
                    l += 1
                    cl = l+1
                    cr = cl+1
                elif abs(n[l]) < abs(n[r]):
                    r-=1
                    if l >0:
                        l-=1
                    cl = l+1
                    cr = cl+1  
                else:
                    l += 1
                    cl = l+1
                    cr = cl+1  

        l = 0

        r = ln-1
        cr = r-1
        cl = cr-1

        while l < r:
            while cl>l:
                s = n[l]+n[cl]+n[cr]+n[r]
                print(l, cl, cr, r, s)
                if s == target:
                    if [n[l], n[cl], n[cr], n[r]] not in res:
                        res.append([n[l], n[cl], n[cr], n[r]])
                    if len(res) > 10:
                        return res
                
                cl-=1

            cr-=1
            cl=cr-1

            if cl<l:
                if abs(n[l]) < abs(n[r]):
                    r -= 1
                    cr = r-1
                    cl = cr-1
                elif abs(n[l]) > abs(n[r]):
                    l+=1
                    if r < ln-1:
                        r+=1
                    cr = r-1
                    cl = cr-1  
                else:
                    r -= 1
                    cr = r-1
                    cl = cr-1  
                    


        return res

# %%
class Solution:
    def fourSum(self, nums: List[int], target: int) -> List[List[int]]:
        nums.sort()
        n = len(nums)
        ans = set()
        for i in range(n):
            for j in range(i+1, n):
                l, r = j + 1, n - 1
                remain = target - nums[i] - nums[j]
                while l < r:
                    if nums[l] + nums[r] == remain:
                        ans.add((nums[i], nums[j], nums[l], nums[r]))
                        l += 1
                        r -= 1
                    elif nums[l] + nums[r] > remain:
                        r -= 1
                    else:
                        l += 1
        return list(map(list, ans))

# %%
n = [1,0,-1,0,-2,2]
n = [-2, -1, 0,0,1,2]
t = 0

# n = [2,2,2,2,2]
# t = 8

# [
#     [-3,-2,2,3],[-3,-1,1,3],[-3,0,0,3],[-3,0,1,2],
#     [-2,-1,0,3],[-2,-1,1,2],[-2,0,0,2],[-1,0,0,1]
# ]


# n = [-3,-2,-1,0,0,1,2,3]
# t = 0

# n = [2,1,0,-1]
# t = 2

# n = [-4,-3,-2,-1,0,0,1,2,3,4]
n = [-5,-4,-3,-2,-1,0,0,1,2,3,4,5]
t = 0

# %%
sol = Solution()
res = sol.fourSum(n, t)
res
# Out:
# [[-3, -2, 1, 4],
#  [-3, -2, 2, 3],
#  [-5, -2, 3, 4],
#  [-5, -3, 3, 5],
#  [-5, -4, 4, 5],
#  [-5, -2, 2, 5],
#  [-4, -2, 2, 4],
#  [-3, -1, 1, 3],
#  [-3, -2, 0, 5],
#  [-4, -2, 1, 5],
#  [-5, 0, 2, 3],
#  [-2, 0, 0, 2],
#  [-2, -1, 0, 3],
#  [-5, -1, 2, 4],
#  [-2, -1, 1, 2],
#  [-4, -1, 2, 3],
#  [-3, -1, 0, 4],
#  [-4, -3, 3, 4],
#  [-5, 0, 1, 4],
#  [-5, -1, 1, 5],
#  [-4, -1, 1, 4],
#  [-4, 0, 1, 3],
#  [-3, 0, 1, 2],
#  [-3, 0, 0, 3],
#  [-4, -3, 2, 5],
#  [-5, 0, 0, 5],
#  [-1, 0, 0, 1],
#  [-4, 0, 0, 4],
#  [-4, -1, 0, 5]]

# %%
# np.array([[-4,-3,3,4],[-4,-2,2,4],[-4,-1,1,4],[-4,-1,2,3],[-4,0,0,4],[-4,0,1,3],[-3,-2,1,4],[-3,-2,2,3],[-3,-1,0,4],[-3,-1,1,3],[-3,0,0,3],[-3,0,1,2],[-2,-1,0,3],[-2,-1,1,2],[-2,0,0,2],[-1,0,0,1]])

np.array([[-5,-4,4,5],[-5,-3,3,5],[-5,-2,2,5],[-5,-2,3,4],[-5,-1,1,5],[-5,-1,2,4],[-5,0,0,5],[-5,0,1,4],[-5,0,2,3],[-4,-3,2,5],[-4,-3,3,4],[-4,-2,1,5],[-4,-2,2,4],[-4,-1,0,5],[-4,-1,1,4],[-4,-1,2,3],[-4,0,0,4],[-4,0,1,3],[-3,-2,0,5],[-3,-2,1,4],[-3,-2,2,3],[-3,-1,0,4],[-3,-1,1,3],[-3,0,0,3],[-3,0,1,2],[-2,-1,0,3],[-2,-1,1,2],[-2,0,0,2],[-1,0,0,1]])
# Out:
# array([[-5, -4,  4,  5],
#        [-5, -3,  3,  5],
#        [-5, -2,  2,  5],
#        [-5, -2,  3,  4],
#        [-5, -1,  1,  5],
#        [-5, -1,  2,  4],
#        [-5,  0,  0,  5],
#        [-5,  0,  1,  4],
#        [-5,  0,  2,  3],
#        [-4, -3,  2,  5],
#        [-4, -3,  3,  4],
#        [-4, -2,  1,  5],
#        [-4, -2,  2,  4],
#        [-4, -1,  0,  5],
#        [-4, -1,  1,  4],
#        [-4, -1,  2,  3],
#        [-4,  0,  0,  4],
#        [-4,  0,  1,  3],
#        [-3, -2,  0,  5],
#        [-3, -2,  1,  4],
#        [-3, -2,  2,  3],
#        [-3, -1,  0,  4],
#        [-3, -1,  1,  3],
#        [-3,  0,  0,  3],
#        [-3,  0,  1,  2],
#        [-2, -1,  0,  3],
#        [-2, -1,  1,  2],
#        [-2,  0,  0,  2],
#        [-1,  0,  0,  1]])

# %%
# [
#     [-3,-2,2,3],[-3,-1,1,3],[-3,0,0,3],[-3,0,1,2],
#     [-2,-1,0,3],[-2,-1,1,2],[-2,0,0,2],[-1,0,0,1]
# ]


[[-3, -2, 2, 3], [-3, -1, 1, 3], [-3, 0, 0, 3], [-3, 0, 1, 2], 
 [-2, -1, 0, 3], [-2, -1, 1, 2], [-2, 0, 0, 2],  [-1, 0, 0, 1]]
# Out:
# [[-3, -2, 2, 3],
#  [-3, -1, 1, 3],
#  [-3, 0, 0, 3],
#  [-3, 0, 1, 2],
#  [-2, -1, 0, 3],
#  [-2, -1, 1, 2],
#  [-2, 0, 0, 2],
#  [-1, 0, 0, 1]]
