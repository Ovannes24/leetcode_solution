# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import List

# %%
"""
012345
------
000000 
000001 
000010 
000011 
000100 
000101 
000110 
000111 +
001000 
001001 
001010 
001011 +
001100 
001101 +
001110 +
001111 
010000 
010001 
010010 
010011 +
010100 
010101 +
010110 +
010111 
011000 
011001 +
011010 +
011011 
011100 +
011101 
011110 
011111 
100000 
100001 
100010 
100011 +
100100 
100101 +
100110 +
100111 
101000 
101001 +
101010 +
101011 
101100 +
101101 
101110 
101111 
110000 
110001 +
110010 +
110011 
110100 +
110101 
110110 
110111 
111000 +
111001 
111010 
111011 
111100 
111101 
111110 
111111 



000111
001011
001101
001110
010011
010101
010110
011001
011010
011100
100011
100101
100110
101001
101010
101100
110001
110010
110100
111000
"""

# %%
# class Solution:
#     def threeSum(self, nums: List[int]) -> List[List[int]]:
#         n = nums
#         ln = len(n)

#         res = []
#         for i in range(ln):
#             for j in range(ln):
#                 if j>i:
#                     for k in range(ln):
#                         if k>j:
#                             if (n[i] != n[j] and n[i] != n[k] and n[j] != n[k]) or (i != j and i != k and j != k):
#                                 if  (n[i] + n[j] + n[k] == 0):
#                                     print(i, j, k)
#                                     res.append([n[i], n[j], n[k]])

#         return res

# %%
class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:
        n = nums
        ln = len(n)

        isDuplicate = False
        res = []
        for i in range(ln):
            for j in range(ln):
                if j>i:
                    for k in range(ln):
                        if k>j:
                            if i != j and i != k and j != k:
                                if  (n[i] + n[j] + n[k] == 0):
                                    print(i, j, k)
                                    for l in res:
                                        if sorted(l) == sorted([n[i], n[j], n[k]]):
                                            isDuplicate = True
                                    if not isDuplicate:
                                        res.append([n[i], n[j], n[k]])
                                    isDuplicate = False

        return res

# %%
# class Solution:
#     def threeSum(self, nums: List[int]) -> List[List[int]]:
#         n = sorted(nums)
#         ln = len(n)
        
#         l = 0
#         r = ln-1
#         c = l+1
#         res = []

#         isRun = True
#         isR = True
#         while isRun:
#             print(l, c, r, n[l] + n[c] + n[r]) 
#             if (n[l] + n[c] + n[r]) == 0:
#                 res.append(n[l], n[c], n[r])

#             if isR:
#                 c+=1
#             else:
#                 c_=1
            
#             if c==r:
#                 isR = False
#                 c-=1
#                 r-=1
#             elif c==l:
#                 isR = True
#                 c+=1
#                 l+=1
#             if r-2 == l:
#                 return res
            
#         return res

# %%
class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:
        n = sorted(nums)
        ln = len(n)

        isDuplicate = False
        res = []
        for i in range(ln):
            for j in range(ln):
                if j>i:
                    for k in range(ln):
                        if k>j:
                            if i != j and i != k and j != k:
                                if  (n[i] + n[j] + n[k] == 0):
                                    print(i, j, k)
                                    for l in res:
                                        if sorted(l) == [n[i], n[j], n[k]]:
                                            isDuplicate = True
                                    if not isDuplicate:
                                        res.append([n[i], n[j], n[k]])
                                    isDuplicate = False

        return res

# %%
class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:
        n = sorted(nums)
        ln = len(n)
        
        if ln == 3:
            if sum(n) != 0:
                return []
        l = 0
        r = ln-1
        c = l+1
        res = []

        isRun = True
        isR = True
        while isRun:
            print(n, l, c, r, '|', n[l], n[c], n[r], '|', n[l] + n[c] + n[r]) 
            if (n[l] + n[c] + n[r]) == 0:
                if [n[l], n[c], n[r]] not in res:
                    res.append([n[l], n[c], n[r]])
            
            c+=1            
            if c>ln-1 or l >ln-1:
                return res
            if n[c]>=n[r]:
                c=l+2
                l=l+1

            if n[l] >= 0:
                l = 0
                c = l+1
                r-=1
                if n[r]<=0:
                    return res
                
            
        return res

# %%
# class Solution:
#     def threeSum(self, nums: List[int]) -> List[List[int]]:
#         res = []
        
#         n = sorted(nums)
#         ln = len(n)

#         for i, j, k in zip(n, n[::-1], n[ln//2:]+n[:ln//2]):
#             print(i,j,k)
#             if sum([i, j, k]) == 0:
#                 res.append([i,j,k])

#         return res

# %%
# class Solution:
#     def threeSum(self, nums: List[int]) -> List[List[int]]:
#         res = []
        
#         n = sorted(nums)
#         ln = len(n)

#         for i, j in zip(range(ln), range(ln)[::-1]):
#             for k in range(i+1, j-1):
#                 print(i,j,k, '|', n[i], n[j], n[k])
#                 if sum([n[i], n[j], n[k]]) == 0:
#                     res.append([n[i], n[j], n[k]])

#         return res

# %%
class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:
        res = []
        
        n = sorted(nums)
        ln = len(n)

        l = 0
        c = l+1
        r = ln-1

        run = True
        while run:
            print(l, c, r, res)
            # if c>=r:
            #     c=l+1
            res_ = [n[l], n[c], n[r]]
            if sum(res_) == 0:
                if res_ not in res:
                    res.append(res_)
            
                if n[c]>0:
                    l+=1
                    c=l
                else:
                    r-=1
                    c=l
                
            
            
            
            c+=1
            if c == r:
                r-=1
                # l=0
                c=l+1
            
            if r-2 == l:
                return res
            
        return res

# %%
class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:
        res = []
        nums.sort()

        for i in range(len(nums)):
            if i > 0 and nums[i] == nums[i-1]:
                continue
            
            j = i + 1
            k = len(nums) - 1

            while j < k:
                total = nums[i] + nums[j] + nums[k]
                # print(i, j, k, res)
                if total > 0:
                    k -= 1
                elif total < 0:
                    j += 1
                else:
                    res.append([nums[i], nums[j], nums[k]])
                    j += 1

                    while nums[j] == nums[j-1] and j < k:
                        j += 1
        
        return res

# %%
# n = [-1,0,1,2,-1,-4]
# n = [-1,-1,-1,1]
# n = [1,1,-2]
# n = [1,1,1]
# n = [-2,0,1,1,2]
# n = np.random.randint(-100, 100, 101)
# n = [-2,0,0,2,2]
# n =[3,0,-2,-1,1,2]
n = [-1,0,1,2,-1,-4,-2,-3,3,0,4]
# n = [0,0,0]

# %%
sol = Solution()
res = sol.threeSum(n)
res
# Out:
# [[-4, 0, 4],
#  [-4, 1, 3],
#  [-3, -1, 4],
#  [-3, 0, 3],
#  [-3, 1, 2],
#  [-2, -1, 3],
#  [-2, 0, 2],
#  [-1, -1, 2],
#  [-1, 0, 1]]

# %%
list_l = []
for i in range(1, 100):
    n = np.arange(-i, i+1)
    list_l.append(len(sol.threeSum(n)))
    print(list_l[-1])
# Out:
# 1
# 2
# 5
# 8
# 13
# 18
# 25
# 32
# 41
# 50
# 61
# 72
# 85
# 98
# 113
# 128
# 145
# 162
# 181
# 200
# 221
# 242
# 265
# 288
# 313
# 338
# 365
# 392
# 421
# 450
# 481
# 512
# 545
# 578
# 613
# 648
# 685
# 722
# 761
# 800
# 841
# 882
# 925
# 968
# 1013
# 1058
# 1105
# 1152
# 1201
# 1250
# 1301
# 1352
# 1405
# 1458
# 1513
# 1568
# 1625
# 1682
# 1741
# 1800
# 1861
# 1922
# 1985
# 2048
# 2113
# 2178
# 2245
# 2312
# 2381
# 2450
# 2521
# 2592
# 2665
# 2738
# 2813
# 2888
# 2965
# 3042
# 3121
# 3200
# 3281
# 3362
# 3445
# 3528
# 3613
# 3698
# 3785
# 3872
# 3961
# 4050
# 4141
# 4232
# 4325
# 4418
# 4513
# 4608
# 4705
# 4802
# 4901

# %%
plt.plot(list_l, '.-')
plt.grid()

# %%
[[-4,0,4],[-4,1,3],[-3,-1,4],[-3,0,3],[-3,1,2],[-2,-1,3],[-2,0,2],[-1,-1,2],[-1,0,1]]
[[-4,0,4],[-4,1,3],          [-3,0,3],[-3,1,2],          [-2,0,2],          [-1,0,1]]
# Out:
# [[-4, 0, 4], [-4, 1, 3], [-3, 0, 3], [-3, 1, 2], [-2, 0, 2], [-1, 0, 1]]

# %%
np.sort(n)
# Out:
# array([-4, -3, -2, -1, -1,  0,  0,  1,  2,  3,  4])

# %%
np.sort(n)
# Out:
# array([-100,  -98,  -94,  -93,  -93,  -91,  -86,  -83,  -82,  -80,  -78,
#         -78,  -78,  -76,  -76,  -74,  -70,  -66,  -64,  -60,  -59,  -54,
#         -53,  -52,  -50,  -49,  -49,  -47,  -46,  -43,  -41,  -41,  -40,
#         -39,  -37,  -31,  -28,  -28,  -28,  -25,  -23,  -22,  -21,  -20,
#         -19,  -18,  -18,  -18,  -14,  -13,  -12,  -11,  -10,   -1,    4,
#           4,    8,    8,    9,   10,   21,   21,   23,   23,   25,   26,
#          26,   27,   28,   29,   29,   30,   33,   35,   36,   37,   37,
#          43,   46,   46,   48,   52,   53,   56,   56,   58,   61,   63,
#          65,   66,   75,   76,   77,   78,   87,   90,   91,   91,   94,
#          95,   96])

# %%
np.sort(n)[::-1]
# Out:
# array([  96,   95,   94,   91,   91,   90,   87,   78,   77,   76,   75,
#          66,   65,   63,   61,   58,   56,   56,   53,   52,   48,   46,
#          46,   43,   37,   37,   36,   35,   33,   30,   29,   29,   28,
#          27,   26,   26,   25,   23,   23,   21,   21,   10,    9,    8,
#           8,    4,    4,   -1,  -10,  -11,  -12,  -13,  -14,  -18,  -18,
#         -18,  -19,  -20,  -21,  -22,  -23,  -25,  -28,  -28,  -28,  -31,
#         -37,  -39,  -40,  -41,  -41,  -43,  -46,  -47,  -49,  -49,  -50,
#         -52,  -53,  -54,  -59,  -60,  -64,  -66,  -70,  -74,  -76,  -76,
#         -78,  -78,  -78,  -80,  -82,  -83,  -86,  -91,  -93,  -93,  -94,
#         -98, -100])

# %%
np.sort(n)[:len(n)//2]
# Out:
# array([-100,  -98,  -94,  -93,  -93,  -91,  -86,  -83,  -82,  -80,  -78,
#         -78,  -78,  -76,  -76,  -74,  -70,  -66,  -64,  -60,  -59,  -54,
#         -53,  -52,  -50,  -49,  -49,  -47,  -46,  -43,  -41,  -41,  -40,
#         -39,  -37,  -31,  -28,  -28,  -28,  -25,  -23,  -22,  -21,  -20,
#         -19,  -18,  -18,  -18,  -14,  -13])

# %%
np.sort(n)[len(n)//2:]
# Out:
# array([-12, -11, -10,  -1,   4,   4,   8,   8,   9,  10,  21,  21,  23,
#         23,  25,  26,  26,  27,  28,  29,  29,  30,  33,  35,  36,  37,
#         37,  43,  46,  46,  48,  52,  53,  56,  56,  58,  61,  63,  65,
#         66,  75,  76,  77,  78,  87,  90,  91,  91,  94,  95,  96])

# %%
plt.plot(n)

# %%
# plt.plot(res[:, 0])
plt.plot(res[:, 1])
# plt.plot(res[:, 2])

# %%
plt.plot(res[:, 0], res[:, 1])

# %%
for i in """000111
001011
001101
001110
010011
010101
010110
011001
011010
011100
100011
100101
100110
101001
101010
101100
110001
110010
110100
111000""".split('\n'):
    print(i, int(i, 2))
# Out:
# 000111 7
# 001011 11
# 001101 13
# 001110 14
# 010011 19
# 010101 21
# 010110 22
# 011001 25
# 011010 26
# 011100 28
# 100011 35
# 100101 37
# 100110 38
# 101001 41
# 101010 42
# 101100 44
# 110001 49
# 110010 50
# 110100 52
# 111000 56

# %%
n = [-1,0,1,2,-1,-4]

# %%
last_l = 0
list_l = []
for i in range(2**10):
    l = sum(list(map(int, bin(i)[2:])))
    if l == 3:
        print(
            (np.argwhere(np.array(list(bin(i)[2:])).astype(int)[::-1] == 1)).reshape(-1), 
            i, 
            i-last_l
        )
        last_l = i
        list_l.append(i)
# Out:
# [0 1 2] 7 7
# [0 1 3] 11 4
# [0 2 3] 13 2
# [1 2 3] 14 1
# [0 1 4] 19 5
# [0 2 4] 21 2
# [1 2 4] 22 1
# [0 3 4] 25 3
# [1 3 4] 26 1
# [2 3 4] 28 2
# [0 1 5] 35 7
# [0 2 5] 37 2
# [1 2 5] 38 1
# [0 3 5] 41 3
# [1 3 5] 42 1
# [2 3 5] 44 2
# [0 4 5] 49 5
# [1 4 5] 50 1
# [2 4 5] 52 2
# [3 4 5] 56 4
# [0 1 6] 67 11
# [0 2 6] 69 2
# [1 2 6] 70 1
# [0 3 6] 73 3
# [1 3 6] 74 1
# [2 3 6] 76 2
# [0 4 6] 81 5
# [1 4 6] 82 1
# [2 4 6] 84 2
# [3 4 6] 88 4
# [0 5 6] 97 9
# [1 5 6] 98 1
# [2 5 6] 100 2
# [3 5 6] 104 4
# [4 5 6] 112 8
# [0 1 7] 131 19
# [0 2 7] 133 2
# [1 2 7] 134 1
# [0 3 7] 137 3
# [1 3 7] 138 1
# [2 3 7] 140 2
# [0 4 7] 145 5
# [1 4 7] 146 1
# [2 4 7] 148 2
# [3 4 7] 152 4
# [0 5 7] 161 9
# [1 5 7] 162 1
# [2 5 7] 164 2
# [3 5 7] 168 4
# [4 5 7] 176 8
# [0 6 7] 193 17
# [1 6 7] 194 1
# [2 6 7] 196 2
# [3 6 7] 200 4
# [4 6 7] 208 8
# [5 6 7] 224 16
# [0 1 8] 259 35
# [0 2 8] 261 2
# [1 2 8] 262 1
# [0 3 8] 265 3
# [1 3 8] 266 1
# [2 3 8] 268 2
# [0 4 8] 273 5
# [1 4 8] 274 1
# ...

# %%
DATA = np.array([
[0,1,2],
[0,1,3],
[0,2,3],
[1,2,3],
[0,1,4],
[0,2,4],
[1,2,4],
[0,3,4], 
[1,3,4], 
[2,3,4], 
[0,1,5], 
[0,2,5], 
[1,2,5], 
[0,3,5], 
[1,3,5], 
[2,3,5], 
[0,4,5], 
[1,4,5], 
[2,4,5], 
[3,4,5], 
[0,1,6], 
[0,2,6], 
[1,2,6], 
[0,3,6], 
[1,3,6], 
[2,3,6], 
[0,4,6], 
[1,4,6], 
[2,4,6], 
[3,4,6], 
[0,5,6], 
[1,5,6], 
[2,5,6], 
[3,5,6], 
[4,5,6], 
[0,1,7], 
[0,2,7], 
[1,2,7], 
[0,3,7], 
[1,3,7], 
[2,3,7] ,
[0,4,7] ,
[1,4,7],
[2,4,7],
[3,4,7],
[0,5,7],
[1,5,7],
[2,5,7],
[3,5,7],
[4,5,7],
[0,6,7],
[1,6,7],
[2,6,7],
[3,6,7],
[4,6,7],
[5,6,7],
[0,1,8],
[0,2,8],
[1,2,8],
[0,3,8],
[1,3,8],
[2,3,8],
[0,4,8],
[1,4,8],
[2,4,8],
[3,4,8],
[0,5,8],
[1,5,8],
[2,5,8],
[3,5,8],
[4,5,8],
[0,6,8],
[1,6,8],
[2,6,8],
[3,6,8],
[4,6,8],
[5,6,8],
[0,7,8],
[1,7,8] ,
[2,7,8] ,
[3,7,8] ,
[4,7,8] ,
[5,7,8] ,
[6,7,8] ,
[0,1,9] ,
[0,2,9] ,
[1,2,9] ,
[0,3,9] ,
[1,3,9] ,
[2,3,9] ,
[0,4,9] ,
[1,4,9] ,
[2,4,9] ,
[3,4,9] ,
[0,5,9] ,
[1,5,9] ,
[2,5,9] ,
[3,5,9] ,
[4,5,9] ,
[0,6,9] ,
[1,6,9] ,
[2,6,9] ,
[3,6,9] ,
[4,6,9] ,
[5,6,9] ,
[0,7,9] ,
[1,7,9] ,
[2,7,9] ,
[3,7,9] ,
[4,7,9] ,
[5,7,9] ,
[6,7,9] ,
[0,8,9] ,
[1,8,9] ,
[2,8,9] ,
[3,8,9] ,
[4,8,9] ,
[5,8,9] ,
[6,8,9] ,
[7,8,9]
])

# %%
plt.plot(DATA[:, 0])
plt.plot(DATA[:, 1])
plt.plot(DATA[:, 2])

# %%
DATA[np.argsort(DATA[:, 0])]
# Out:
# array([[0, 1, 2],
#        [0, 1, 7],
#        [0, 2, 7],
#        [0, 3, 7],
#        [0, 4, 7],
#        [0, 5, 7],
#        [0, 6, 7],
#        [0, 1, 8],
#        [0, 2, 8],
#        [0, 4, 8],
#        [0, 5, 6],
#        [0, 5, 8],
#        [0, 7, 8],
#        [0, 1, 9],
#        [0, 2, 9],
#        [0, 3, 9],
#        [0, 4, 9],
#        [0, 5, 9],
#        [0, 6, 9],
#        [0, 7, 9],
#        [0, 8, 9],
#        [0, 6, 8],
#        [0, 4, 6],
#        [0, 3, 8],
#        [0, 1, 5],
#        [0, 3, 6],
#        [0, 3, 5],
#        [0, 4, 5],
#        [0, 2, 4],
#        [0, 1, 6],
#        [0, 1, 4],
#        [0, 3, 4],
#        [0, 2, 5],
#        [0, 2, 6],
#        [0, 2, 3],
#        [0, 1, 3],
#        [1, 5, 8],
#        [1, 2, 5],
#        [1, 3, 8],
#        [1, 2, 8],
#        [1, 4, 8],
#        [1, 6, 8],
#        [1, 2, 4],
#        [1, 3, 4],
#        [1, 2, 9],
#        [1, 3, 9],
#        [1, 4, 9],
#        [1, 5, 9],
#        [1, 2, 3],
#        [1, 6, 9],
# ...

# %%
plt.plot(np.diff(list_l))
plt.grid()

# %%
plt.plot(list_l)
plt.grid()

# %%
bin(10)[2:]
# Out:
# '1010'
